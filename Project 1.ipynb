# %% [markdown]
# # **Develop a Simple Data Analysis Application with Machine Learning model**

# %% [markdown]
# ## **DATA INPUT**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/heart (1).csv')

# %% [markdown]
# Loading the dataset named "students performance"

# %% [markdown]
# ## **DATA PROCESSING**

# %%
df.shape
# Out:
# (1025, 14)

# %% [markdown]
# It provides the number of rows and columns in the given dataset

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# This method is useful to show the first 5 rows of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# It provides the overview of the dataframe that include index range, number of entries, non-null counts, data types and memory usage.

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %% [markdown]
# It generates the statistics for numerical columns that includes count, mean, standard deviation, minimum value, maximum value, 25%, 50%, 25% quartiles.

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# It provides the number of null values in each column of the dataframe

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# *  It is used to remove the duplicate rows in the dataframe
# *  Here "inplace=True" is used to replace the original df instead of assigning it in the another variable.

# %%
df_encoded=pd.get_dummies(df,drop_first=True)

# %% [markdown]
# It converts all the categorical columns into numerical columns.

# %%
df[['age','trestbps','target']].mean(axis=1)
# Out:
# 0      59.000000
# 1      64.333333
# 2      71.666667
# 3      69.666667
# 4      66.666667
#          ...
# 723    63.000000
# 733    51.000000
# 739    60.000000
# 843    73.000000
# 878    58.000000
# Length: 302, dtype: float64

# %% [markdown]
# *  It is used to calculate the mean value of math score, reading score and writing score of the students in the column wise.
# *  Here "Axis=1" is used to access in the column wise.

# %%
df.groupby('sex')[['age','trestbps','target']].mean()
# Out:
#            age    trestbps    target
# sex
# 0    55.677083  133.083333  0.750000
# 1    53.834951  130.912621  0.446602

# %% [markdown]
# This groups the dataframe by gender and calculate it average of math score,reading score and writing score.

# %%
df.groupby('chol')[['age','trestbps','target']].mean()
# Out:
#        age  trestbps  target
# chol
# 126   57.0     150.0     1.0
# 131   57.0     130.0     0.0
# 141   44.0     108.0     1.0
# 149   60.0     115.0     0.5
# 157   41.0     120.0     1.0
# ...    ...       ...     ...
# 394   62.0     140.0     1.0
# 407   63.0     150.0     0.0
# 409   56.0     134.0     0.0
# 417   65.0     140.0     1.0
# 564   67.0     115.0     1.0
#
# [152 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['chol'].plot(kind='hist', bins=20, title='chol')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['trestbps'].plot(kind='hist', bins=20, title='trestbps')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['target'].plot(kind='hist', bins=20, title='target')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='chol', y='age', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='age', y='trestbps', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='trestbps', y='target', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['chol']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('chol', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('chol')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['chol']
#   ys = series['trestbps']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('chol', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('chol')
# _ = plt.ylabel('trestbps')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['chol']
#   ys = series['target']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('chol', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('chol')
# _ = plt.ylabel('target')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['chol']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'chol'}, axis=1)
#               .sort_values('chol', ascending=True))
#   xs = counted['chol']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('chol', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('chol')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['chol'].plot(kind='line', figsize=(8, 4), title='chol')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['trestbps'].plot(kind='line', figsize=(8, 4), title='trestbps')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['target'].plot(kind='line', figsize=(8, 4), title='target')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# This groups the dataframe by parental level of education and calculate it average of math score,reading score and writing score.

# %%
df.value_counts()
# Out:
# age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# 77   1    0   125       304   0    0        162      1      0.0      2      3   2     0         1
# 29   1    1   130       204   0    0        202      0      0.0      2      0   2     1         1
# 34   0    1   118       210   0    1        192      0      0.7      2      0   2     1         1
#      1    3   118       182   0    0        174      0      0.0      2      0   2     1         1
# 35   0    0   138       183   0    1        182      0      1.4      2      0   2     1         1
#                                                                                                ..
# 41   0    1   105       198   0    1        168      0      0.0      2      1   2     1         1
# 40   1    3   140       199   0    1        178      1      1.4      2      0   3     1         1
#           0   152       223   0    1        181      0      0.0      2      0   3     0         1
#               110       167   0    0        114      1      2.0      1      0   3     0         1
# 39   1    2   140       321   0    0        182      0      0.0      2      0   2     1         1
# Name: count, Length: 302, dtype: int64

# %% [markdown]
# This method provides the unique values count of the dataframe.

# %%
df.columns.unique()
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# It returns all unique column names of the dataframe.

# %%
df['sex'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df['target'],bins=20,kde=True,color='darkblue')
plt.title("fds")
plt.xlabel("target")
plt.ylabel("oldpeak")
# Out:
# Text(0, 0.5, 'oldpeak')

# %% [markdown]
# The above histogram shows how many students performs in writing.

# %%
sns.countplot(x='thalach',data=df, palette='Set2')
plt.title("Ditribution of exang")
plt.xlabel("thalach")
plt.ylabel("oldpeak")
plt.show()
# Out:
# <ipython-input-24-fa44abd30e75>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='thalach',data=df, palette='Set2')

# %% [markdown]
# The countplot shows that most of the students did not completed the test preparation course only few students completed the test preparation course.

# %%
sns.boxplot(x='sex',y='target',data=df, palette='Set2')
plt.title("target by sex")
plt.xlabel("sex")
plt.ylabel("target")
plt.show()
# Out:
# <ipython-input-26-083398fe3d89>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='sex',y='target',data=df, palette='Set2')

# %% [markdown]
# *   It visualizes the distribution of writing scores for each gender.
# *   It shows median, quartiles and outliers.

# %%
Q1=df['target'].quantile(0.25)
Q2=df['target'].median()
Q3=df['target'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers=df[(df['target']<lower_bound) | (df['target']>upper_bound)]
print("Lower Bound:",lower_bound)
print("Upper Bound:",upper_bound)
print("Outliers:")
print(outliers)
outliers_removed = df[(df['target'] >= lower_bound) & (df['target'] <= upper_bound)]
plt.figure(figsize=(8, 5))
sns.histplot(outliers_removed['target'], bins=15, kde=True, color='darkblue')
plt.axvline(lower_bound, color='red', linestyle='--', label='Lower Bound')
plt.axvline(upper_bound, color='green', linestyle='--', label='Upper Bound')
plt.title('target Distribution (Outliers Removed)')
plt.xlabel('target')
plt.ylabel('thalach')
plt.legend()
plt.show()
# Out:
# Lower Bound: -1.5
# Upper Bound: 2.5
# Outliers:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %% [markdown]
# ## **MODEL DEVELOPMENT**

# %%
x=df_encoded.drop(columns=['target'])
y=df_encoded['target']

# %% [markdown]
# In this, x variable contains the input features by dropping the target values. y variable contains only the target value which 'writing score'

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# *   Here train_test_split() is a function from sklearn that splits the dataset into the following:
#
#
# 1.  **x_train:** It contains 80 % of the input data to train the model.
# 2.   **x_test:** It contains 20 % of the input data to test the model.
# 3. **y_train:** It contains 80 % of the target variable.
# 4.   **y_test:** It contains 20 % of the target variable.
